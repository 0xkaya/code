# %% [markdown]
# # Importing Packages

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preperation

# %% [markdown]
# ## Loading the Data

# %%
(X_train, y_train),(X_test,y_test) = fashion_mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000,)

# %% [markdown]
# ### Preprocessing the Data

# %%
X_train = X_train.reshape(-1,28*28).astype('float32')/255
X_test = X_test.reshape(-1,28*28).astype('float32')/255
y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

# %% [markdown]
# # Building a Model

# %% [markdown]
# ## Defining the Feedforward Neural Network

# %%
model = Sequential([
    Dense(256, input_shape=(784,), activation ='relu', name='L1'),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(128, activation ='relu', name='L2'),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(64, activation ='relu', name='L3'),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(10, activation ='softmax', name='L4')
], name = 'FeedForward'
)

# %% [markdown]
# ## Compiling the model

# %%
model.compile(
    optimizer ='adam',
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %% [markdown]
# ## Train the model

# %%
history = model.fit(X_train, y_train, 
                    epochs=20, 
                    batch_size=128, 
                    validation_split = 0.2, 
)
# Out:
# Epoch 1/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.6840 - accuracy: 0.7621 - val_loss: 0.4659 - val_accuracy: 0.8267
# Epoch 2/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4826 - accuracy: 0.8293 - val_loss: 0.4204 - val_accuracy: 0.8461
# Epoch 3/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4456 - accuracy: 0.8435 - val_loss: 0.3714 - val_accuracy: 0.8648
# Epoch 4/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4261 - accuracy: 0.8474 - val_loss: 0.3886 - val_accuracy: 0.8594
# Epoch 5/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4083 - accuracy: 0.8546 - val_loss: 0.3611 - val_accuracy: 0.8698
# Epoch 6/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3942 - accuracy: 0.8576 - val_loss: 0.3735 - val_accuracy: 0.8618
# Epoch 7/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3891 - accuracy: 0.8593 - val_loss: 0.3592 - val_accuracy: 0.8691
# Epoch 8/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3773 - accuracy: 0.8658 - val_loss: 0.3394 - val_accuracy: 0.8774
# Epoch 9/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3700 - accuracy: 0.8669 - val_loss: 0.3788 - val_accuracy: 0.8620
# Epoch 10/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3626 - accuracy: 0.8710 - val_loss: 0.3576 - val_accuracy: 0.8700
# Epoch 11/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3571 - accuracy: 0.8693 - val_loss: 0.3691 - val_accuracy: 0.8697
# Epoch 12/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3532 - accuracy: 0.8720 - val_loss: 0.3572 - val_accuracy: 0.8749
# Epoch 13/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3491 - accuracy: 0.8728 - val_loss: 0.3528 - val_accuracy: 0.8742
# Epoch 14/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3456 - accuracy: 0.8749 - val_loss: 0.3309 - val_accuracy: 0.8790
# Epoch 15/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3307 - accuracy: 0.8783 - val_loss: 0.3448 - val_accuracy: 0.8733
# Epoch 16/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3304 - accuracy: 0.8785 - val_loss: 0.3326 - val_accuracy: 0.8787
# Epoch 17/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3274 - accuracy: 0.8832 - val_loss: 0.3339 - val_accuracy: 0.8791
# Epoch 18/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3236 - accuracy: 0.8824 - val_loss: 0.3342 - val_accuracy: 0.8772
# Epoch 19/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3235 - accuracy: 0.8832 - val_loss: 0.3330 - val_accuracy: 0.8798
# Epoch 20/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3153 - accuracy: 0.8843 - val_loss: 0.3261 - val_accuracy: 0.8860

# %% [markdown]
# # Evaluating the model

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose =0)
print(f"Test Accuracy: {test_accuracy: .4f}")
# Out:
# Test Accuracy:  0.8800

# %% [markdown]
# ## Predictions

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred,axis =1)
y_true_classes = np.argmax(y_test,axis =1)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ## Classification Report

# %%
print("Classiffication Report:\n", classification_report(y_true_classes,y_pred_classes,target_names=[ 
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot" 
    ]))
# Out:
# Classiffication Report:
#                precision    recall  f1-score   support
#
#  T-shirt/top       0.81      0.85      0.83      1000
#      Trouser       0.99      0.97      0.98      1000
#     Pullover       0.82      0.76      0.79      1000
#        Dress       0.89      0.86      0.87      1000
#         Coat       0.78      0.81      0.80      1000
#       Sandal       0.99      0.95      0.97      1000
#        Shirt       0.67      0.70      0.69      1000
#      Sneaker       0.94      0.95      0.95      1000
#          Bag       0.98      0.97      0.97      1000
#   Ankle boot       0.94      0.97      0.95      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %%
model.summary()
# Out:
# Model: "FeedForward"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  L1 (Dense)                  (None, 256)               200960
#
#  batch_normalization_12 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  L2 (Dense)                  (None, 128)               32896
#
#  batch_normalization_13 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  L3 (Dense)                  (None, 64)                8256
#
#  batch_normalization_14 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  L4 (Dense)                  (None, 10)                650
#
# =================================================================
# Total params: 244,554
# Trainable params: 243,658
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# ## Confusion Matrix

# %%
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# %%
### Plotting the confusion Matrix
plt.figure(figsize=(10,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',xticklabels =[
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
], yticklabels=[
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"])
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ### Plotting the training and validation accuracy and loss

# %%
plt.figure(figsize=(14,5))

# Accuracy plot
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'],label ='Training Accuracy')
plt.plot(history.history['val_accuracy'],label ='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc = 'lower right')

# Loss plot
plt.subplot(1,2,2)
plt.plot(history.history['loss'],label ='Training Loss')
plt.plot(history.history['val_loss'],label ='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc = 'lower right')

plt.tight_layout()
plt.show()

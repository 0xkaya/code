# %% [markdown]
# # Importing Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ## Data Preperation

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target  # True labels (for comparison purposes)

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA to reduce dimensions to 2 for easy visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# # Clustering

# %%
# Run K-means clustering with K=3 (since we know there are 3 species in the data)
K = 3
kmeans = KMeans(n_clusters=K, random_state=42)
kmeans.fit(X_scaled)
cluster_labels = kmeans.labels_

# %% [markdown]
# # Plotting

# %%
# Plot the clusters and centroids
plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=cluster_labels, cmap='viridis', marker='o', edgecolor='k', s=50, label="Clustered Data Points")
centroids_pca = pca.transform(kmeans.cluster_centers_)
plt.scatter(centroids_pca[:, 0], centroids_pca[:, 1], color='red', marker='x', s=200, label="Centroids")
plt.title("K-means Clustering on the Iris Dataset")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.legend()
plt.show()

# %%
# Optional: Check clustering performance by comparing with true labels
from sklearn.metrics import accuracy_score
# Note: K-means cluster labels are arbitrary; use permutation mapping for accuracy comparison if desired.
print("Cluster Centers (in original dimensions):\n", kmeans.cluster_centers_)
# Out:
# Cluster Centers (in original dimensions):
#  [[ 1.13597027  0.08842168  0.99615451  1.01752612]
#  [-1.01457897  0.85326268 -1.30498732 -1.25489349]
#  [-0.05021989 -0.88337647  0.34773781  0.2815273 ]]
